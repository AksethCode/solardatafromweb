# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# Define the URL
url = "https://www.re-plus.com/see-whos-attending/"

# Send an HTTP GET request to the URL and parse the HTML content
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the table element by its HTML tag name
    table = soup.find('table')

    if table:
        # Find all table rows (tr) and extract data
        table_data = []
        for row in table.find_all('tr'):
            row_data = [cell.text.strip() for cell in row.find_all('td')]
            table_data.append(row_data)

        # Convert the table data into a Pandas DataFrame
        df = pd.DataFrame(table_data, columns=None)

        # Display the DataFrame
        print(df)
    else:
        print("No table found on the page.")
else:
    print(f"Failed to retrieve the web page. Status code: {response.status_code}")
# Out:
#                                         0                          1  \
# 0                                    None                       None
# 1                    1 SUN SOLAR ELECTRIC           EARTHRISE ENERGY
# 2                              127 ENERGY  EAST BAY COMMUNITY ENERGY
# 3                                  149MKM            EAST COAST WIND
# 4                       149MKM ELECTRICAL                 EAST GROUP
# ...                                   ...                        ...
# 1768  EAGLERISE ELECTRIC ELECTRONIC CHINA         LAKEY CONSTRUCTION
# 1769                            EAGLEVIEW     LAMBO RENEWABLE ENERGY
# 1770               EAGLEVIEW TECHNOLOGIES               LAMINAR HVAC
# 1771    EARTHLIGHT SOLAR ENERGY SOLUTIONS       LAMPARA SOLAR MEXICO
# 1772                EARTHLINGS 20 PODCAST
#
#                            2              3
# 0                       None           None
# 1     LAND LIBERTY COALITION            SDC
# 2                   LANDGATE     SDC ENERGY
# 3             LANDMARK SOLAR          SDG E
# 4                  LANDPOINT      SDG SOLAR
# ...                      ...            ...
# 1768   SCOUT ENERGY PARTNERS  ZONBIX TAIWAN
# 1769            SCOUT METALS        ZONERGY
# 1770                SCREENCO   ZORLU ENERGY
# 1771   SCUDDER ROOFING SOLAR            ZSG
# 1772                SD MYERS     ZURN SOLAR
#
# [1773 rows x 4 columns]

# %%
flattend_data=df.values.flatten().tolist()

# %%
flattend_data
# Out:
# [None,
#  None,
#  None,
#  None,
#  '1 SUN SOLAR ELECTRIC',
#  'EARTHRISE ENERGY',
#  'LAND LIBERTY COALITION',
#  'SDC',
#  '127 ENERGY',
#  'EAST BAY COMMUNITY ENERGY',
#  'LANDGATE',
#  'SDC ENERGY',
#  '149MKM',
#  'EAST COAST WIND',
#  'LANDMARK SOLAR',
#  'SDG E',
#  '149MKM ELECTRICAL',
#  'EAST GROUP',
#  'LANDPOINT',
#  'SDG SOLAR',
#  '15 LIGHTYEARS',
#  'EAST KENTUCKY POWER COOPERATIVE',
#  'LANDSOLUTIONS',
#  'SDI SACRAMENTO DRILLING',
#  '16 PENNY',
#  'EAST LUX ENERGY TECHNOLOGY SHENZHEN',
#  'LANDWEHR CONSTRUCTION',
#  'SE',
#  '174 POWER GLOBAL',
#  'EAST SIDE SOLAR HOLDINGS',
#  'LANGAN ENGINEERING ENVIRON',
#  'SEA BOX',
#  '1832 ASSET MANAGEMENT',
#  'EASTERN POWER SOLUTIONS',
#  'LANGAN ENGINEERING ENVIRONMENTAL SERVICES',
#  'SEA BRIGHT SOLAR',
#  '1CLIMATE',
#  'EASY LOGISTICS MANAGEMENT WAREHOUSING',
#  'LARSEN TOUBRO',
#  'SEA CHANGE',
#  '1SOLAR',
#  'EATON',
#  'LARSEN TOUBRO LTD DIGITAL SOLUTIONS PT D',
#  'SEAL FOR LIFE INDUSTRIES',
#  '1ST LIGHT ENERGY',
#  'EATON TRIPP LITE',
#  'LAS VEGAS GLOBAL ECONOMIC ALLIANCE',
#  'SEAL METHODS',
#  '1ST SOURCE BANK',
#  'EB HORSMAN SON',
#  'LAS VEGAS POWER PROFESSIONALS',
#  'SEAL SOLAR',
#  '1UP SOLAR',
#  'EBLC',
#  'LAS VEGAS REVIEW JOURNAL',
#  'SEAM GROUP',
#  '2798575 ONTARIO',
#  'EC FENNELL PA CONSULTANTS',
#  'LAS VEGAS SUN GREENSPUN MEDIA GROUP',
#  'SEARING INDUSTRIES',
#  '2R GROUP',
#  'ECA SOLAR',
#  'LATHAM WATKINS',
#  'SEASIDE STEEL',
#  '360 ELECTRICIAN',
#  'ECC',
#  'LATIMER CONTROLS',
#  'SEATTLE CITY LIGHT',
#  '360 INDUSTRIAL SERVICES',
#  'ECHO ENVIRONMENTAL',
#  'LATTICE ENERGY',
#  'SEAWARD ELECTRONIC',
#  '3DEGREES GROUP',
#  'ECO DISTRIBUTING',
#  'LATVENERGO',
#  'SEAWARD GROUP USA',
#  '3E',
#  'ECO ENERGY',
#  'LAVO DIGITAL',
#  'SEBHO POWER CONSTRUCTION',
#  '3GM STEEL',
#  'ECO ENGINEERING',
#  'LAW EPC CONSULTING',
#  'SECOND GENERATION ENERGY',
#  '3J CONSULTING',
#  'ECO FOUNDATIONS',
#  'LAW OFFICE OF JOSEPH F WIEDMAN',
#  'SECURITY SEED SERVICES',
#  '3M',
#  'ECO HABITAT',
#  'LAWRENCE BERKELEY NATIONAL LAB',
#  'SEDA SEQUOIA ENGINEERING DESIGN ASSOCIATES',
#  '3SUN',
#  'ECO MANAGEMENT SYSTEMS',
#  'LAWRENCE BERKELEY NATIONAL LABORATORY',
#  'SEED ELECTRONICS',
#  '42 RENEWABLES',
#  'ECO POWER',
#  'LAZARD',
#  'SEEL',
#  '4D SUPPLY CHAIN CONSULTING',
#  'ECO SPARK ENERGY',
#  'LAZEN SOLAR',
#  'SEEPEX',
#  '4JET MICROTECH',
#  'ECO SPLASH SYNERGY',
#  'LBNL',
#  'SEER SOLAR',
#  '4K ALUMINUM',
#  'ECOCENTRIX',
#  'LEADING EDGE MFG',
#  'SEG SOLAR',
#  '4PRO ENERGY',
#  'ECODIRECT',
#  'LEAF',
#  'SEGUE SUSTAINABLE INFRASTRUCTURE',
#  '4R ENERGY US',
#  'ECOFASTEN SOLAR',
#  'LEAFY POWER SOLUTIONS MEXICO',
#  'SEINE',
#  '4STEL ENGINEERING',
#  'ECOFLOW TECHNOLOGY',
#  'LEAP',
#  'SEL CONSTRUCTION',
#  '59 NORTH CAPITAL',
#  'ECOFORCE SOLUTIONS',
#  'LEAPTON SOLAR CHANGSHU',
#  'SELF EMPLOYED',
#  '7C SOLARPARKEN',
#  'ECOGREEN SOLUTIONS',
#  'LEAPTRAN',
#  'SEMA COALITION',
#  '7SKYLINE',
#  'ECOGY ENERGY',
#  'LEARNEWABLE',
#  'SEMAPSOLAR',
#  '816 SOLAR PROS',
#  'ECOGY SOLAR',
#  'LECANGS',
#  'SEMIC ENGINEERING TRADING',
#  '93ENERGY',
#  'ECOLED',
#  'LECTRK',
#  'SEMIC ENGINEERING TRAINING',
#  'A BETTER CHOICE CONSULTING',
#  'ECONERGY',
#  'LEES POWER WUXI CHINA',
#  'SEMINOLE ELECTRIC COOPERATIVE',
#  'A RENT TEST EQUIPMENT',
#  'ECONERGY FORTCON',
#  'LEEWARD RENEWABLE ENEGRY',
#  'SEMINOLE FINANCIAL SERVICES',
#  'A TEAM ROOFING SOLAR',
#  'ECONETICS',
#  'LEEWARD RENEWABLE ENERGY',
#  'SEMPER SOLARIS',
#  'A1 SOLARSTORE',
#  'ECONOMIC COMMERCIAL SERVICE NASSAU',
#  'LEGACY CLASSIC TRUCKS',
#  'SEMPRA INFRASTRUCTURE',
#  'A123 SYSTEMS',
#  'ECOPLEXUS',
#  'LEGACY EXPRESS TRUCKING',
#  'SEN SOLAR SYSTEM',
#  'AAA SOLAR WORKS',
#  'ECOPOWER DEVELOPMENT',
#  'LEGACY SOLAR',
#  'SENDERO ENERGY SERVICES',
#  'AAH HAA',
#  'ECOPOWER ENERGIA SOLAR',
#  'LEGRAND',
#  'SENECA ENVIRONMENTAL',
#  'AARDEX',
#  'ECOPOWER IEMCO',
#  'LEIDOS',
#  'SENERGY TECHNICAL SERVICES USA',
#  'AARTECH SOLONICS',
#  'ECOPRENEUR ALLIES',
#  'LEIDOS ENGINEERING',
#  'SENGA ENERGY',
#  'AARUSH POWER TECH',
#  'ECOPROGETTI SRL',
#  'LEK CONSULTING',
#  'SENSE',
#  'AB CARVAL INVESTORS',
#  'ECOPULSE',
#  'LEMOINE',
#  'SENSEHAWK',
#  'ABA ENTERPRISES',
#  'ECOPULSE SA DE CV',
#  'LEMON DROP SOLAR',
#  'SENTREX WIND SERVICES',
#  'ABAAD CONTRACTING',
#  'ECOS ENERGY',
#  'LEOCH BATTERY',
#  'SENTRO',
#  'ABB',
#  'ECOSAVE',
#  'LEOCH R BATTERY',
#  'SENVA SENSORS',
#  'ABB CHINA',
#  'ECOSOLAR HAWAII',
#  'LEVELTEN ENERGY',
#  'SEOUL WOMEN S UNIVERSITY',
#  'ABB E MOBILITY',
#  'ECOSOLARHAWAII',
#  'LEVERAGE LAW GROUP',
#  'SEQUENCE CONSULTING',
#  'ABBI GROUP',
#  'ECOTRENDS',
#  'LEVITON',
#  'SEQUOIA CAPITAL GLOBAL EQUITIES',
#  'ABBOTT INTERFAST',
#  'ECOVOLE',
#  'LEVITON MANUFACTURING',
#  'SER CAPITAL PARTNERS',
#  'ABC ALUMINUM',
#  'ECP',
#  'LEVITON MFG',
#  'SERVERDOMES',
#  'ABC SOLAR',
#  'ECS MIDWEST',
#  'LEWIS ASSOCIATES',
#  'SERVICE FINANCE',
#  'ABC SUPPLY',
#  'ECS SOUTHEAST',
#  'LEYLINE RENEWABLE CAPITAL',
#  'SERVINCA SERVICIOS DE INGENIERIA SA',
#  'ABLOOMAX',
#  'ECS SOUTHWEST',
#  'LG E ENERGY SERVICES',
#  'SESA SOLAR ENERGY STORAGE ASSOCIATION OF PUERTO RICO',
#  'ABO WIND CANADA',
#  'ED SOLAR INDUSTRY',
#  'LG ELECTRONICS',
#  'SESAME SOLAR',
#  'ABOVE',
#  'ED2 MATERIALS',
#  'LG ENERGY SOLUTION',
#  'SET ELEC',
#  'ABOVE SURVEYING',
#  'EDDES SUSTAINABILITY SOLUTIONS',
#  'LG ENERGY SOLUTION VERTECH',
#  'SEUNGHWA TECHNOLOGIES',
#  'ABRELEC',
#  'EDF INNOVATION LAB',
#  'LG ENERGY SOLUTIONS VERTECH',
#  'SEVO INDUSTRIAL FIRE PROTECTION',
#  'ABS',
#  'EDF RENEWABLES',
#  'LGCY POWER',
#  'SEYSES',
#  'ABSCOPE ENVIRONMENTAL',
#  'EDF RENEWABLES NORTH AMERICA',
#  'LGE ELECTRICAL SALES',
#  'SF CLIMATE WEEK',
#  'ABUSSUAN GROUP',
#  'EDG',
#  'LHB',
#  'SFA ELECTRIC',
#  'ABYSS BATTERY',
#  'EDGE RENEWABLE PARTNERS',
#  'LI CYCLE',
#  'SFC',
#  'AC POWER',
#  'EDGECOM ENERGY',
#  'LIBERTY',
#  'SFW',
#  'AC SOLAR WAREHOUSE',
#  'EDGED ENERGY',
#  'LIBERTY POWER',
#  'SG',
#  'ACB',
#  'EDGELI',
#  'LIBERTY UTILITIES',
#  'SG ENERGY',
#  'ACCEL HR SOLUTIONS',
#  'EDISON ELECTRIC INSTITUTE',
#  'LIBOMARK GROUP',
#  'SGRE',
#  'ACCELDEV',
#  'EDISON ENERGY',
#  'LIBRA ENERGY',
#  'SHAANXI TESSON NEW ENERGY',
#  'ACCELERATE WIND',
#  'EDISON TECHNOLOGIES',
#  'LIBSYS',
#  'SHANDONG QUANWEI NEW ENERGY TECHNOLOGY',
#  'ACCELERGEN ENERGY',
#  'EDOIQ',
#  'LIFESTYLE SOLAR',
#  'SHANDONG TAIHE ENERGY STOCK',
#  'ACCESS INTELLIGENCE POWER MAGAZINE',
#  'EDP',
#  'LIFETIME',
#  'SHANDONG TIANHAN NEW TECHNOLOGY',
#  'ACCESS POWER SOLUTIONS',
#  'EDP RENEWABLES',
#  'LIFI LED',
#  'SHANGHAI HEMESSE EXHIBITION SERVICE',
#  'ACCESS WORLD',
#  'EDP RENEWABLES NORTH AMERICA',
#  'LIGHT EDISON',
#  'SHANGHAI HUITIAN NEW MATERIAL',
#  'ACCIONA ENERGY',
#  'EDPR',
#  'LIGHT WAY SOLAR',
#  'SHANGHAI JUXIN HAIJU NEW ENERGY TECHNOLOGY',
#  'ACCORD POWER',
#  'EDSCO FASTENERS',
#  'LIGHTEDISON',
#  'SHANGHAI NEW ENERGY INDUSTRY ASSOCIATION',
#  'ACCORD REAL ESTATE INVESTMENTS',
#  'EDWARD MARCS PHILIPPINES',
#  'LIGHTHOUSE SOLAR',
#  'SHANGHAI RUNHOOD POWER',
#  'ACCUENERGY CANADA',
#  'EDWARDS LIFESCIENCES',
#  'LIGHTHOUSESOLAR',
#  'SHANGHAI SUNBY SOLAR TECHNOLOGY',
#  'ACCUFY ANALYTICS',
#  'EE',
#  'LIGHTSOURCE BP',
#  'SHAOXING JUNMAI CROSS BORDER ECOMMERCE',
#  'ACCULON ENERGY',
#  'EECA',
#  'LIGHTSOURCE RENEWABLE ENERGY US',
#  'SHARED SOLAR ADVISORS USA',
#  'ACCURE BATTERY INTELLIGENCE',
#  'EEPLUS',
#  'LIGHTSOURCEBP',
#  'SHARI HAUG CONSULTING',
#  'ACCUSOLAR',
#  'EEQUALS',
#  'LIGHTSOURECEBP',
#  'SHARP ELECTRONICS',
#  'ACD GLOBAL',
#  'EFFECT ENERGY',
#  'LIGHTSTAR RENEWABLES',
#  'SHARP SYSTEMS',
#  'ACE BATTERY',
#  'EFFECTIVE SOLAR PRODUCTS',
#  'LIGHTWAVE SOLAR ELECTRIC',
#  'SHELL',
#  'ACE ENGINEERING',
#  'EFFICIENCY MANITOBA',
#  'LIME ROCK NEW ENERGY',
#  'SHELL ENERGY',
#  'ACENTECH',
#  'EFFICIENT POWER LIGHT',
#  'LIMITLESS SOLAR',
#  'SHELL ENERGY SOLUTIONS',
#  'ACIP ENERGY CONSULTING',
#  'EFICIENCIA ENERGETICA FOUNDATION',
#  'LINAK',
#  'SHELL LUBRICANT SOLUTIONS',
#  'ACMEPOINT ENERGY SERVICES',
#  'EFS ENERGY',
#  'LINCOLN INDUSTRIES',
#  'SHELL LUBRICANTS',
#  'ACN ENERGY SOLUTION',
#  'EFSUS BILISIM',
#  'LINDSAY PRECAST',
#  'SHELL NEW ENERGIES US',
#  'ACN ENERGY SOLUTIONS',
#  'EGAN',
#  'LINEA ENERG',
#  'SHELL OIL PRODUCTS',
#  'ACNENERGY SOLUTION',
#  'EGAUGE SYSTEMS',
#  'LINEA ENERGY',
#  'SHENHAI NEW ENERGY TECHNOLOGY SHANDONG',
#  'ACNS',
#  'EGCP',
#  'LINETECHSOLAR',
#  'SHENZHEN ACE BATTERY CO LTD SHENZHEN BAK ENERGY',
#  'ACP',
#  'EGE HAINA',
#  'LINFINITY',
#  'SHENZHEN AEROSPACE ELECTRONIC',
#  'ACR SOLAR',
#  'EIA',
#  'LINK STAFFING SERVICES',
#  'SHENZHEN AHONY POWER',
#  'ACRADYNE',
#  'EIFFEL IG',
#  'LINKLATERS',
#  'SHENZHEN AMPOWER NEW ENERGY',
#  'ACS APPRENTICESHIP',
#  'EIG EVERGREEN INNOV',
#  'LINKUS',
#  'SHENZHEN ANYGAP NEW ENERGY',
#  'ACT POWER SERVICES',
#  'EINSTEIN RENEWABLES',
#  'LINTON CRYSTAL TECHNOLOGIES',
#  'SHENZHEN APOLLO ENERGY HOLDING LTDS',
#  'ACTION ENERGY',
#  'EIP',
#  'LINXON US',
#  'SHENZHEN ATESS POWER TECHNOLOGY',
#  'ACTION FACE',
#  'EIQ ENERGY',
#  'LION ENERGY',
#  'SHENZHEN BAIDIBAO INNOVATIVE TECHNOLOGY',
#  'ACTION SOLAR',
#  'EITRI FOUNDRY',
#  'LION POWER',
#  'SHENZHEN BAIQIANCHENG ELECTRONIC',
#  'ACTIVE SOLAR DEVELOPMENT',
#  'EK FOX',
#  'LIPOWER TECHNOLOGY GUANGZHOU',
#  'SHENZHEN BELY ENERGY TECHNOLOGY',
#  'ACTIVEPROSPECT',
#  'EK FOX ASSOCIATES',
#  'LIST LOGISTICS',
#  'SHENZHEN CHL INDUSTRIES',
#  'AD HOC GROUP',
#  'EKABEL',
#  'LITEON',
#  'SHENZHEN CLOU ELECTRONICS',
#  'ADAMS ELECTRIC',
#  'EKO INSTRUMENTS USA',
#  'LITHIUM UPGRADE',
#  'SHENZHEN CORSCA ELECTRONIC',
#  'ADANI SOLAR',
#  'EKPO FUEL CELL TECHNOLOGIES',
#  'LITHOVA ENERGY TECHNOLOGY',
#  'SHENZHEN CTECHI TECHNOLOGY',
#  'ADAPTIPHY ENERGY SOLUTIONS',
#  'EKS ENERGY',
#  'LITTELFUSE',
#  'SHENZHEN CYCLEN TECHNOLOGY',
#  'ADAPTURE RENEWABLES',
#  'EL DJARAISSI MOTORS',
#  'LIUM RESEARCH',
#  'SHENZHEN DESUN SOLAR TECHNOLOGY',
#  'ADENA POWER',
#  'EL DJARISSI MOTORS',
#  'LIUNA ONTARIO DISTRICT COUNCIL',
#  'SHENZHEN DIDALAIDIAN TECHNOLOGY',
#  'ADEO',
#  'EL MERCURIO',
#  'LIUNA PACIFIC SOUTHWEST REGION',
#  'SHENZHEN DONGJIAXIN WIRE CABLE',
#  'ADERIS ENERGY',
#  'EL PASO ELECTRIC',
#  'LIVART GROUP',
#  'SHENZHEN EENOVANCE ENERGY TECHNOLOGY',
#  'ADLER ELEKTROTECHNIK LEIPZIG',
#  'ELC ENERGY',
#  'LIVE GUARD TECH',
#  'SHENZHEN EN PLUS TECH',
#  'ADOLUS TECHNOLOGY',
#  'ELCCO',
#  'LIVE OAK BANK',
#  'SHENZHEN ENERSHARE TECHNOLOGY',
#  'ADON RENEWABLES',
#  'ELCO LAND SERVICES',
#  'LIVEWIRE CONSTRUCTION',
#  'SHENZHEN ENVICOOL TECHNOLOGY',
#  'ADON RENEWABLES TEPCO',
#  'ELDRIDGE ROOFING SOLAR',
#  'LIVEWIRE ENERGY',
#  'SHENZHEN ET EXPO DEISGN SERVICES',
#  'ADT COMMERCIAL',
#  'ELECNOR HAWKEYE',
#  'LIVINGSTON HAVEN',
#  'SHENZHEN FBTECH ELECTRONICS',
#  'ADT SOLAR',
#  'ELECTRA SALES',
#  'LIWATT CONTEMPORARY AMPEREX TECHNOLOGY',
#  'SHENZHEN FLEXTECH',
#  'ADUU SOLAR',
#  'ELECTRIC CITY SOLAR',
#  'LJR INDUSTRIES',
#  'SHENZHEN FPR',
#  'ADVANCE COMPONENTS',
#  'ELECTRIC FACTORY ENERGY',
#  'LLR PARTNERS',
#  'SHENZHEN FRENDA TECH',
#  'ADVANCE ENERGY',
#  'ELECTRIC HYDROGEN',
#  'LM HYDRO ECO DOO',
#  'SHENZHEN GAOPENG ENERGY TECHNOLOGY',
#  'ADVANCE INDUSTRIAL MFG',
#  'ELECTRIC POWER ENGINEERS',
#  'LMK',
#  'SHENZHEN GLORY INDUSTRIES',
#  'ADVANCE SOLAR',
#  'ELECTRIC POWER RESEARCH INSTITUTE EPRI',
#  'LMM INNOVATION GROUP',
#  'SHENZHEN GRENERGY TECHNOLOGY',
#  'ADVANCED DIGITAL CABLE',
#  'ELECTRIC SUPPLY',
#  'LOAD MANAGEMENT',
#  'SHENZHEN GROWATT NEW ENERGY',
#  'ADVANCED ENERGY',
#  'ELECTRICAL COMPANY CUCUMACAYAN',
#  'LOADSTAR',
#  'SHENZHEN GSL ENERGY',
#  'ADVANCED ENERGY EFFICIENCIES',
#  'ELECTRICARE',
#  'LOAN HOMI',
#  'SHENZHEN GUANKE TECHNOLOGY',
#  'ADVANCED POWER LIGTING SYSTEMS',
#  'ELECTRICIAN SANTA CRUZ',
#  'LOAN PROGRAMS OFFICE US DEPARTMENT OF ENERGY',
#  'SHENZHEN HAISIC TECHNOLOGY',
#  'ADVANCED POWER SERVICES NA',
#  'ELECTRICITY DEPARTMENT GOVERNMENT OF GOA',
#  'LOCAL 400 IBEW',
#  'SHENZHEN HIGHPOWER TECHNOLOGY',
#  'ADVANCED POWER SOLUTIONS',
#  'ELECTRIQ POWER',
#  'LOCAL SOLAR',
#  'SHENZHEN HONGJIA INTERNATIONAL SUPPLY CHAIN MANAGEMENT',
#  'ADVANCED SOLAR POWER HANGZHOU',
#  'ELECTRO CABLES',
#  'LOCAL SOLAR FOR ALL',
#  'SHENZHEN HOUNY BATTERY',
#  'ADVANCED SOLAR PRODUCTS',
#  'ELECTRO MECHANICAL INDUSTRIES',
#  'LOCAL UNION 364 IBEW',
#  'SHENZHEN HUAXING NEW ENERGY TECHNOLOGY',
#  'ADVANCED TEST EQUIPMENT',
#  'ELECTROMECANICA NUNEZ SRL',
#  'LOCK JOINT TUBE',
#  'SHENZHEN HUIN INTERNATIONAL LOGISTICS',
#  'ADVANTAGE AUSTRIA',
#  'ELECTRON CAPITAL PARTNERS',
#  'LOCKE LORD',
#  'SHENZHEN HYSINCERE BATTERY',
#  'ADVANTAGE CAPITAL',
#  'ELECTRONIC CONCEPTS',
#  'LOCKHEED MARTIN ENERGY STORAGE',
#  'SHENZHEN JDDTECH NEW MATERIAL',
#  'ADVANTECH',
#  'ELECTRUM',
#  'LOCKTON',
#  'SHENZHEN JINSDON LIGHTING TECHNOLOGY',
#  'ADVENT CAPITAL MANAGEMENT',
#  'ELEKTRIK',
#  'LOCKTON COMPANIES',
#  'SHENZHEN JINSHIDUN LIGHTING TECHNOLOGY',
#  'ADVENT ENERGY',
#  'ELEKTRIK APP',
#  'LOCKWOOD',
#  'SHENZHEN JINXURI NEW ENERGY TECHNOLOGY',
#  'AE SOLAR ALTERNATIVE ENERGY',
#  'ELEKTROMREZA SRBIJE',
#  'LOCTEK',
#  'SHENZHEN JREPOWER TECH',
#  'AECON UTILITIES',
#  'ELEKTROPRIVREDA SRBIJE',
#  'LOCUZ',
#  'SHENZHEN KERUI POWER STORAGE',
#  'AECON UTILITIES US',
#  'ELEMENT ENERGY',
#  'LODESTAR ENERGY',
#  'SHENZHEN KINGSMILE E COMMERCE',
#  'AEE SOLAR',
#  'ELEMENTAL ENERGY',
#  'LOGICFINDER',
#  'SHENZHEN KOKO ELECTRONIC',
#  'AEG',
#  'ELEMENTAL EXCELERATOR',
#  'LOGISTICS PLUS INC',
#  'SHENZHEN KUNTENG',
#  'AEG INTERNATIONAL',
#  'ELERA RENEWABLE BROOKFIELD',
#  'LOGISTICUS GROUP',
#  'SHENZHEN KWUNPHI ROBOT',
#  'AEI SOLAR',
#  'ELERA RENOVAVEIS',
#  'LOGISTICUS TECHNOLOGY SOLUTIONS',
#  'SHENZHEN LEAGEND OPTOELECTRONICS',
#  'AEP ENERGY',
#  'ELEVATE',
#  'LONE PINE CAPITAL',
#  'SHENZHEN LETSOLAR TECHNOLOGY',
#  'AEP ONSITE PARTNERS',
#  'ELEVATE POWER',
#  'LONEOPTICS',
#  'SHENZHEN LIGHT BLUE INNOVATION INDUSTRY',
#  'AEROCOMPACT',
#  'ELEVATE RENEWABLE ENERGY',
#  'LONESTAR',
#  'SHENZHEN LITHIUM VALLEY TECHNONGY',
#  'AERONET WORLDWIDE',
#  'ELEVATE RENEWABLES',
#  'LONESTAR ELECTRIC SUPPLY',
#  'SHENZHEN LITHTECH ENERGY',
#  'AEROSEAL',
#  'ELEVATED STAFFING SUPPORT',
#  'LONESTAR SOLAR SERVICES',
#  'SHENZHEN LUX POWER TECHNOLOGY',
#  'AEROSHIELD ETAJOULE',
#  'ELEVATION',
#  'LONG DURATION ENERGY STORAGE COUNCIL',
#  'SHENZHEN MAT GROUP',
#  'AEROTEK',
#  'ELIN ENERJI',
#  'LONGFELLOW',
#  'SHENZHEN MEGAREVO TECHNOLOGY',
#  'AES',
#  'ELIO ENERGY GROUP',
#  'LONGI HYDROGEN',
#  'SHENZHEN MINGLIDA PRECISION TECHNOLOGY',
#  'AES CLEAN ENERGY',
#  'ELIOS SOLAR',
#  'LONGI SOLAR TECHNOLOGY US',
#  'SHENZHEN MY SMART ENERGY ELECTRIC',
#  'AES DISTRIBUTED ENERGY',
#  'ELITE RENEWABLE ENERGY SERVICES',
#  'LONGROAD ENERGY',
#  'SHENZHEN OLYS',
#  'AES EL SALVADOR',
#  'ELITE SOLAR',
#  'LONGROAD ENERGY HOLDINGS',
#  'SHENZHEN PECRON TECHNOLOGY',
#  'AES NEXT',
#  'ELITE SOLAR INTEGRATION',
#  'LOOM SOLAR',
#  'SHENZHEN PORTABLE ELECTRONIC TECHNOLOGY',
#  'AESC US',
#  'ELIWOOD',
#  'LOOP GLOBAL',
#  'SHENZHEN POWEALTHY TIMES NEW ENERGY TECHNOLOGY',
#  'AETERNA ENERGY',
#  'ELKRAFT SVERIGE',
#  'LOTUS ENERGY SYSTEMS',
#  'SHENZHEN POWEROAK NEWENER',
#  'AETHER INVESTMENT PARTNERS',
#  'ELLENSBURG SOLAR',
#  'LOVELAND INNOVATIONS',
#  'SHENZHEN RYDER ELECTRONICS',
#  'AFC SOLAR',
#  'ELLIOTT ELECTRIC SUPPLY',
#  'LOW CARBON',
#  'SHENZHEN SAFECLOUD ENERGY',
#  'AFFILIATED ENGINEERS',
#  'ELM MICROGRID',
#  'LOW CARBON ENERGY',
#  'SHENZHEN SENERGY TECHNOLOGY',
#  'AFFORDABLE EQUITY PARTNERS',
#  'ELPRESS',
#  'LOWES',
#  'SHENZHEN SINOPOWER TECHNOLOGY',
#  'AFFORDABLE EXTERIORS',
#  'ELSE ENERGY',
#  'LPL SOLAR',
#  'SHENZHEN SMK NEW ENERGY TECHNOLOGY',
#  'AFFORDABLE SOLAR',
#  'ELSEWEDY ELECTRIC',
#  'LRE',
#  'SHENZHEN SOLA E TECHNOLOGY',
#  'AFFORDABLE SOLAR CAYMAN',
#  'ELTAS TRANSFORMATOR',
#  'LS CABLE SYSTEM',
#  'SHENZHEN SOLARPRO TECH',
#  'AFFORDABLE SOLAR ROOF AIR',
#  'ELUM',
#  'LS CABLE SYSTEM USA',
#  'SHENZHEN SOSEN INNOVATION TECHNOLOGY',
#  'AFORE NEW ENERGY TECHNOLOGY SHANGHAI',
#  'ELYSIUM SOLAR ENERGY',
#  'LS ELECTRIC',
#  'SHENZHEN SUNGOLD SOLAR',
#  'AFQ ALNOOR',
#  'EM GLOBAL ENGINEERING',
#  'LS ELECTRIC AMERICA',
#  'SHENZHEN SUNNEW ENERGY',
#  'AFRICAN ENERGY',
#  'EMA ELECTROMECHANICS',
#  'LS ENERGY SOLUTIONS',
#  'SHENZHEN TECTRONIC TECHNOLOGY',
#  'AG CON',
#  'EMBOLD RESEARCH',
#  'LS POWER',
#  'SHENZHEN TOP TEK TECHNOLOGY',
#  'AG ELECTRIC',
#  'EMC',
#  'LS POWER EQUITY ADVISORS',
#  'SHENZHEN TOPBAND BATTERY',
#  'AG ENERGIES',
#  'EMERALDX',
#  'LSC ENVIRONMENTAL PRODUCTS',
#  'SHENZHEN UFO POWER TECHNOLOGY',
#  'AG MARKETING SEVEN SOLAR',
#  'EMEREN',
#  'LSE',
#  'SHENZHEN UUGREENPOWER',
#  'AG TECHNOLOGIES',
#  'EMEREN US',
#  'LUCID SOLAR',
#  'SHENZHEN UZ ENERGY',
#  'AGA GROUP',
#  'EMERGE ALLIANCE',
#  'LUIS MANUEL SANCHEZ ENERGY',
#  'SHENZHEN WANGYIN EXHIBITION SERVICE',
#  'AGATHON SOLAR',
#  'EMERSON',
#  'LUMIFARO',
#  'SHENZHEN WELDTEC TECHNOLOGY TRADE',
#  'AGC CHEMICALS AMERICAS',
#  'EMERSON SOLAHD',
#  'LUMIN',
#  'SHENZHEN WELINK TECH',
#  'AGENCY SALES',
#  'EMERY POWER',
#  'LUMINACE',
#  'SHENZHEN YIWASHI TECHNOLOGY',
#  'AGERE ENERGY INFRASTRUCTURE PARTNERS',
#  'EMIG',
#  'LUMINARX CAPITAL MANAGEMENT',
#  'SHENZHEN YUNFAN POWER TECHNOLOGY',
#  'AGERE INFRASTRUCTURE PARTNERS',
#  'EMMONS OLIVIER RESOURCES INC EOR',
#  'LUMINATE',
#  'SHENZHEN YUNJI NEW ENERGY TECHNOLOGY',
#  'AGETO ENERGY',
#  'EMMVEE PHOTOVOLTAIC POWER',
#  'LUMINIA',
#  'SHENZHEN ZESECO LI ION RECYCLING TECH',
#  'AGGREKO',
#  'EMPACT TECHNOLOGOES',
#  'LUMIO HX',
#  'SHENZHEN ZHILAI SCI TECH',
#  'AGGREKO ENERGY TRANSITION SOLUTIONS',
#  'EMPIRE RENEWABLE ENERGY',
#  'LUMMIFY',
#  'SHENZHENBASENTECHNOLOGYCO',
#  'AGILE WIND POWER',
#  'EMPORIA',
#  'LUNAR ENERGY',
#  'SHENZHENFUDENGTECHNOLOGYCO',
#  'AGILITAS ENERGY',
#  'EMPORIA ENERGY',
#  'LUVTERRA',
#  'SHENZHENHGNEWENERGYINDUSTRIALCO',
#  'AGILITECH',
#  'EMPOWER AMERICA',
#  'LUXORIGO',
#  'SHERMCO',
#  'AGNI SOLAR SYSTEMS PVT',
#  'EMPOWER ENERGIES',
#  'LUZ ENERGY',
#  'SHERMCO INDUSTRIES',
#  'AGORA SUPPLY',
#  'EMPOWER ENERGIES CLEAN INFRASTRUCTURE',
#  'LVI ASSOCIATES',
#  'SHERWIN WILLIAMS',
#  'AGREATE',
#  'EMPOWER HOME',
#  'LW SURVEY',
#  'SHIFTED ENERGY',
#  'AGRIGOLD INTERNATIONAL',
#  'EMPOWER SOLAR',
#  'LW SURVEY COMPANY LAND SURVEYING MAPPING SERVICES',
#  'SHINE',
#  'AGRIPOWER SOLAR',
#  'EMPRESA NACIONAL DE ENERGIA SOLAR SA',
#  'LXI RENEWABLES CAPITAL',
#  'SHINE ENERGY TECHNOLOGY',
#  'AGUILLON ENTERPRISES',
#  'EMPYREAL POWER',
#  'LYDETCO',
#  'SHINE SOLAR',
#  'AHOUSSI HOLDING',
#  'EMRGY',
#  'LYNAC LITHIUM TECHNOLOGY',
#  'SHINENERGY TECHNOLOGY ANHUI',
#  'AHZ CONSULTING ENGINEERS',
#  'EMS PARTNERS',
#  'LYNN ELLIOTT',
#  'SHIPSTER',
#  'AI RENEWABLES',
#  'EMUN METAL ENGINEERING',
#  'LYNX ENGINEERING',
#  'SHIPWAY CONSTRUCTIONS',
#  'AICON SOLAR',
#  'EN ENGINEERING',
#  'LYRA SOLAR',
#  'SHIRDAN GROUP SOLAREEF',
#  'AIM DYNAMICS',
#  'ENACT SYSTEMS',
#  'M BAR C CONSTRUCTION',
#  'SHIVE HATTERY',
#  'AIM HIGH',
#  'ENBRIDGE',
#  'M2 FEDERAL',
#  'SHOALS PARENT',
#  'AIMBRIDGE ENERGY GROUP',
#  'ENBRIDGE GAS',
#  'MAAN ALUMINIUM',
#  'SHOALS TECHNOLOGIES GROUP',
#  'AIMS POWER',
#  'ENCAP ENERGY TRANSITION',
#  'MABDAA ALTAQADUM',
#  'SHOP SOLAR KITS',
#  'AIR LIQUIDE',
#  'ENCAP INVESTMENTS',
#  'MABILLE SOLAR PARTNERS',
#  'SHREENATH SMART TECHNOLOGIES',
#  'AIREKO ENERGY AEG',
#  'ENCOLOR',
#  'MAC AUTO SPORTS',
#  'SHRI MARUTI TRAVELS SMT ATPL ASSOCIATES',
#  'AIREKO ENERGY SOLUTION',
#  'ENCOMPASS CAPITAL',
#  'MAC AUTOSPORT',
#  'SHUANGDENG GROUP',
#  'AIRSPOOL',
#  'ENCOMPASS SERVICES',
#  'MAC AUTOSPORTS',
#  'SHYLEE S CONSTRUCTION',
#  'AIRSTREAM SERVICES',
#  'ENCOMPASSED TECH SOLUTIONS',
#  'MACKINNON PARTNERS',
#  'SIBA FUSES',
#  'AIRSYS COOLING TECHNOLOGIES',
#  'ENCOR SOLAR',
#  'MACQUARIE',
#  'SICAME NORTH AMERICA',
#  'AIRTOUCH SOLAR',
#  'ENCORE RENEWABLE ENERGY',
#  'MADDOX INDUSTRIAL TRANSFORMER',
#  'SICHUAN FEITESEN NEWENERGY',
#  'AIRWAVE GREENTECH',
#  'ENCORE WIRE',
#  'MADISON ENERGY INVESTMENTS',
#  'SICKLE SOLAR',
#  'AIRWAY SERVICES',
#  'ENDEAVOR BUSINESS MEDIA',
#  'MAENUM METAL SUPPLY',
#  'SIDEWINDER SOLAR',
#  'AISPEX',
#  'ENDEAVOR ENERGY',
#  'MAFFEI STRUCTURAL ENGINEERING',
#  'SIEKON ENERGY STORAGE',
#  'AK POWER SOLUTIONS',
#  'ENDEAVOUR ENERGY',
#  'MAG ENERGY',
#  'SIEMENS',
#  'AK SOLAR PRODUCTS',
#  'ENDURANS SOLAR',
#  'MAGIC SUN SOLAR',
#  'SIEMENS ENERGY',
#  'AKAYSHA ENERGY',
#  'ENDURANT',
#  'MAGNETRON',
#  'SIEMENS FINANCIAL SERVICES',
#  'AKCOME',
#  'ENDURENERGY SYSTEMS',
#  'MAGNIFIELD',
#  'SIEMENS GAMESA',
#  'AKCOME USA',
#  'ENEL NORTH AMERICA',
#  'MAGNUS GREEN SOLAR',
#  'SIEMENS INDUSTRY',
#  'AKHEPRAN INTERNATIONAL ACADEMY',
#  'ENEL X NORTH AMERICA',
#  'MAHOCO AGRIBIZ',
#  'SIEMENS SI',
#  'AKINAL BELLA',
#  'ENEON ES',
#  'MAIN ELECTRIC SUPPLY',
#  'SIERRA ALUMINUM',
#  'AKON SOLAR',
#  'ENEOS POWER USA',
#  'MAIN STREET SOLAR',
#  'SIERRA THERMAL',
#  'AKRON PRODUCTS',
#  'ENER I AI',
#  'MAINE COMMUNITY SOLAR MARYLAND COMMUNITY SOLAR',
#  'SIERRATHERMAL',
#  'AKUO',
#  'ENERBIZ',
#  'MAINS ELECTRIC',
#  'SIGMA',
#  'AKUO ENERGY USA',
#  'ENERCON',
#  'MAJR RESOURCES',
#  'SIGNAL ENERGY',
#  'AL DHUWAIB',
#  'ENERCON ENGINEERING',
#  'MAKIM TEKNOLOJI',
#  'SIGNAL ENERGY CONSTRUCTORS',
#  'AL HABAK',
#  'ENERCON SERVICES',
#  'MALAMA SOLAR',
#  'SIGNAL GROUP',
#  'AL KHALIL CONSTRUCTION COMPANY PVT',
#  'ENERFIN RENEWABLES',
#  'MALLIKA ASHWIN MAYA CORPORATION DBA MAM',
#  'SIGNATURE SOLAR',
#  'AL MAIDAN AL MASSY',
#  'ENERFLO',
#  'MALLORY GROUP',
#  'SIIX USA',
#  'AL RAAD',
#  'ENERG MAGAZINE',
#  'MANA GROUP',
#  'SILFAB SOLAR',
#  'AL RAED',
#  'ENERGA',
#  'MANGO POWER',
#  'SILICON RANCH',
#  'AL RUQI AL MOTAMAYEZ',
#  'ENERGATE ENERJI URETIM SAN VE TIC',
#  'MANHARD CONSULTING',
#  'SILICON VALLEY BANK',
#  'AL UMNIA MEDICAL',
#  'ENERGATE SOLAR',
#  'MANN SOLAR',
#  'SILICON VALLEY BANK A DIVISION OF FIRST CITIZENS BANK',
#  'AL ZAD GROUP',
#  'ENERGEA GLOBAL',
#  'MANTIS INNOVATION',
#  'SILISIUMTECH',
#  'ALABAMA SOLAR INDUSTRY ASSOCIATION ALASEIA',
#  'ENERGEIAWORKS',
#  'MANUFACTURED ASSEMBLIES',
#  'SILVERFOX MANAGEMENT',
#  'ALAKHYAR',
#  'ENERGETIC CAPITAL',
#  'MANUFACTURED ASSEMBLIES CORP LLC MAC',
#  'SILVERLINE',
#  'ALAN ROCHE',
#  'ENERGETIC INSURANCE',
#  'MAP INTERNATIONAL',
#  'SILVERLINE COMMUNICATIONS',
#  'ALANIS',
#  'ENERGIA VERDE ALTERNATIVA EVA MEXICO',
#  'MAPLEMARK BANK',
#  'SILVERLINE HOME REMODELING',
#  'ALARM',
#  'ENERGIEKONTOR',
#  'MARATHON CAPITAL',
#  'SILVERPEAK',
#  'ALASKA CENTER FOR ENERGY POWER UAF EQUITABLE SOLAR SOLUTION',
#  'ENERGIX',
#  'MARCOR CONSTRUCTION SOLAR INSTALLATIONS',
#  'SILVERPEAK RENEWABLES INVESTMENT PARTNERS',
#  'ALBA ENERGY',
#  'ENERGIX RENEWABLE ENERGIES',
#  'MARCUM',
#  'SIME CI',
#  'ALBERICI',
#  'ENERGIX RENEWABLES',
#  'MAREX SPECTRON',
#  'SIMPLE DYNAMIX',
#  'ALCA METALS INDONESIA',
#  'ENERGIZED VENTURES',
#  'MARINE FASTENERS',
#  'SIMPLE POWER',
#  'ALCALDIA MUNICIPAL DE LISLIQUE',
#  'ENERGOSUN INVESTMENT ZRT',
#  'MARKING SERVICES',
#  'SIMPLE TREE DIGITAL',
#  'ALCALDIA MUNICIPAL DE POLOROS',
#  'ENERGPORT',
#  'MARMON IEI',
#  'SIMPLERAY',
#  'ALCO',
#  'ENERGY',
#  'MARMON INDUSTRIAL ENERGY INFRASTRUCTURE',
#  'SIMPLEX ENGINEERING',
#  'ALCO BUILDING SOLUTIONS',
#  'ENERGY AGENCY',
#  'MARQUIS SOLAR FRAME WORKS',
#  'SIMPLY SOLAR',
#  'ALDER',
#  'ENERGY ALLIES',
#  'MARS RENEWABLE',
#  'SIMPLY SOLAR SOCAL',
#  'ALDER ENERGY SYSTEMS',
#  'ENERGY ASSURANCE',
#  'MARSH',
#  'SINBON USA',
#  'ALDRIDGE',
#  'ENERGY AUTHORITY',
#  'MARSH MCLENNAN AGENCY',
#  'SINCLAIR DESIGNS ENGINEERING',
#  'ALERAN',
#  'ENERGY AUTOMATION PAKISTAN PVT',
#  'MARSH USA',
#  'SINCLAIR DIGITAL',
#  'ALEX YANG',
#  'ENERGY CONCEPTS',
#  'MARSHALL STEVENS',
#  'SINCLAIR DIGITAL SERVICES',
#  'ALEXUS SOLAR',
#  'ENERGY DEFENDERS',
#  'MARTEN LAW',
#  'SINENG ELECTRIC',
#  'ALFA SOLAR',
#  'ENERGY DEPOT',
#  'MARTIN ENERGY GROUP',
#  'SINEXCEL',
#  ...]
